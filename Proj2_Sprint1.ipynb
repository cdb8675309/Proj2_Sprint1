# %%
import pandas as pd
import numpy as np

#red_wine = pd.read_csv('/Users/cd/Documents/Code Academy Berlin/Project 2/wine+quality/winequality-red.csv')

# %%
red_wine = pd.read_csv('/Users/cd/Documents/Code Academy Berlin/Project 2/wine+quality/winequality-red.csv', sep = ';')

# %%
red_wine.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
# 9                 17.0                 102.0   0.9978  3.35       0.80
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5
# 5      9.4        5
# 6      9.4        5
# 7     10.0        7
# 8      9.5        7
# 9     10.5        5

# %%
red_wine_copy = red_wine.copy()

# %%
red_wine.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1589            6.6             0.725         0.20             7.8      0.073
# 1590            6.3             0.550         0.15             1.8      0.077
# 1591            5.4             0.740         0.09             1.7      0.089
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1589                 29.0                  79.0  0.99770  3.29       0.54
# 1590                 26.0                  35.0  0.99314  3.32       0.82
# 1591                 16.0                  26.0  0.99402  3.67       0.56
# 1592                 29.0                  40.0  0.99574  3.42       0.75
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1589      9.2        5
# 1590     11.6        6
# 1591     11.6        6
# 1592     11.0        6
# 1593      9.5        6
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6

# %%
red_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
red_wine.shape
# Out:
# (1599, 12)

# %%
red_wine.isnull().values.any()
# Out:
# False

# %%
red_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
def add_underscores(red_wine):
    red_wine.columns = red_wine.columns.str.replace(' ', '_')
    return red_wine

# %%
red_wine = add_underscores(red_wine)
red_wine.head(5)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
red_wine['quality_label'] = red_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# %%
# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
red_wine['quality_label'] = pd.Categorical(red_wine['quality_label'],
categories=['low', 'medium', 'high'])

# %%
white_wine = pd.read_csv('/Users/cd/Documents/Code Academy Berlin/Project 2/wine+quality/winequality-white.csv', sep = ';')

# %%
white_wine_copy = white_wine.copy()

# %%
white_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %%
def add_underscores(white_wine):
    white_wine.columns = white_wine.columns.str.replace(' ', '_')
    return white_wine

# %%
white_wine = add_underscores(white_wine)
white_wine.head(5)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
white_wine['quality_label'] = white_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# %%
# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
white_wine['quality_label'] = pd.Categorical(white_wine['quality_label'],
categories=['low', 'medium', 'high'])

# %%
white_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         4898 non-null   float64
#  1   volatile_acidity      4898 non-null   float64
#  2   citric_acid           4898 non-null   float64
#  3   residual_sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free_sulfur_dioxide   4898 non-null   float64
#  6   total_sulfur_dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
#  12  quality_label         4898 non-null   category
# dtypes: category(1), float64(11), int64(1)
# memory usage: 464.2 KB

# %%
white_wine.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %%
white_wine.head(10)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# 9            8.1              0.22         0.43             1.5      0.044
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
# 5                 30.0                  97.0   0.9951  3.26       0.44
# 6                 30.0                 136.0   0.9949  3.18       0.47
# 7                 45.0                 170.0   1.0010  3.00       0.45
# 8                 14.0                 132.0   0.9940  3.30       0.49
# 9                 28.0                 129.0   0.9938  3.22       0.45
#
#    alcohol  quality quality_label
# 0      8.8        6        medium
# 1      9.5        6        medium
# 2     10.1        6        medium
# 3      9.9        6        medium
# 4      9.9        6        medium
# 5     10.1        6        medium
# 6      9.6        6        medium
# 7      8.8        6        medium
# 8      9.5        6        medium
# 9     11.0        6        medium

# %%
white_wine.sort_values('quality_label', ascending=False)
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 281             6.1              0.31         0.58             5.0      0.039
# 827             7.4              0.24         0.36             2.0      0.031
# 2522            7.3              0.17         0.24             8.1      0.121
# 3754            5.4              0.46         0.15             2.1      0.026
# 820             6.6              0.36         0.29             1.6      0.021
# ...             ...               ...          ...             ...        ...
# 3182            5.5              0.12         0.33             1.0      0.038
# 3179            8.5              0.20         0.40             1.1      0.046
# 3177            5.6              0.41         0.22             7.1      0.050
# 1293            6.9              0.39         0.22             4.3      0.030
# 1055            8.6              0.26         0.41             2.2      0.049
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 281                  36.0                 114.0  0.99090  3.30       0.60
# 827                  27.0                 139.0  0.99055  3.28       0.48
# 2522                 32.0                 162.0  0.99508  3.17       0.38
# 3754                 29.0                 130.0  0.98953  3.39       0.77
# 820                  24.0                  85.0  0.98965  3.41       0.61
# ...                   ...                   ...      ...   ...        ...
# 3182                 23.0                 131.0  0.99164  3.25       0.45
# 3179                 31.0                 106.0  0.99194  3.00       0.35
# 3177                 44.0                 154.0  0.99310  3.30       0.40
# 1293                 10.0                 102.0  0.99300  3.00       0.87
# 1055                 29.0                 111.0  0.99410  2.96       0.44
#
#       alcohol  quality quality_label
# 281      12.3        8          high
# 827      12.5        9          high
# 2522     10.4        8          high
# 3754     13.4        8          high
# 820      12.4        9          high
# ...       ...      ...           ...
# 3182      9.8        5           low
# 3179     10.5        4           low
# 3177     10.5        5           low
# 1293     11.6        4           low
# 1055     10.0        5           low
#
# [4898 rows x 13 columns]

# %%
red_wine.sort_values('quality', ascending=False)
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 495            10.7             0.350         0.53            2.60      0.070
# 1403            7.2             0.330         0.33            1.70      0.061
# 390             5.6             0.850         0.05            1.40      0.045
# 1061            9.1             0.400         0.50            1.80      0.071
# 1202            8.6             0.420         0.39            1.80      0.068
# ...             ...               ...          ...             ...        ...
# 690             7.4             1.185         0.00            4.25      0.097
# 1478            7.1             0.875         0.05            5.70      0.082
# 899             8.3             1.020         0.02            3.40      0.084
# 1299            7.6             1.580         0.00            2.10      0.137
# 832            10.4             0.440         0.42            1.50      0.145
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 495                   5.0                  16.0  0.99720  3.15       0.65
# 1403                  3.0                  13.0  0.99600  3.23       1.10
# 390                  12.0                  88.0  0.99240  3.56       0.82
# 1061                  7.0                  16.0  0.99462  3.21       0.69
# 1202                  6.0                  12.0  0.99516  3.35       0.69
# ...                   ...                   ...      ...   ...        ...
# 690                   5.0                  14.0  0.99660  3.63       0.54
# 1478                  3.0                  14.0  0.99808  3.40       0.52
# 899                   6.0                  11.0  0.99892  3.48       0.49
# 1299                  5.0                   9.0  0.99476  3.50       0.40
# 832                  34.0                  48.0  0.99832  3.38       0.86
#
#       alcohol  quality quality_label
# 495      11.0        8          high
# 1403     10.0        8          high
# 390      12.9        8          high
# 1061     12.5        8          high
# 1202     11.7        8          high
# ...       ...      ...           ...
# 690      10.7        3           low
# 1478     10.2        3           low
# 899      11.0        3           low
# 1299     10.9        3           low
# 832       9.9        3           low
#
# [1599 rows x 13 columns]

# %%
white_wine.sort_values('quality', ascending=False)
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 827             7.4              0.24         0.36            2.00      0.031
# 1605            7.1              0.26         0.49            2.20      0.032
# 876             6.9              0.36         0.34            4.20      0.018
# 774             9.1              0.27         0.45           10.60      0.035
# 820             6.6              0.36         0.29            1.60      0.021
# ...             ...               ...          ...             ...        ...
# 1484            7.5              0.32         0.24            4.60      0.053
# 2373            7.6              0.48         0.37            1.20      0.034
# 251             8.5              0.26         0.21           16.20      0.074
# 1688            6.7              0.25         0.26            1.55      0.041
# 253             5.8              0.24         0.44            3.50      0.029
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 827                  27.0                 139.0  0.99055  3.28       0.48
# 1605                 31.0                 113.0  0.99030  3.37       0.42
# 876                  57.0                 119.0  0.98980  3.28       0.36
# 774                  28.0                 124.0  0.99700  3.20       0.46
# 820                  24.0                  85.0  0.98965  3.41       0.61
# ...                   ...                   ...      ...   ...        ...
# 1484                  8.0                 134.0  0.99580  3.14       0.50
# 2373                  5.0                  57.0  0.99256  3.05       0.54
# 251                  41.0                 197.0  0.99800  3.02       0.50
# 1688                118.5                 216.0  0.99490  3.55       0.63
# 253                   5.0                 109.0  0.99130  3.53       0.43
#
#       alcohol  quality quality_label
# 827      12.5        9          high
# 1605     12.9        9          high
# 876      12.7        9          high
# 774      10.4        9          high
# 820      12.4        9          high
# ...       ...      ...           ...
# 1484      9.1        3           low
# 2373     10.4        3           low
# 251       9.8        3           low
# 1688      9.4        3           low
# 253      11.7        3           low
#
# [4898 rows x 13 columns]

# %%
combined_wines_desc = pd.concat([red_wine.describe(), white_wine.describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
combined_wines_desc
# Out:
#       Red Wines Stats                                               \
#         fixed_acidity volatile_acidity  citric_acid residual_sugar
# count     1599.000000      1599.000000  1599.000000    1599.000000
# mean         8.319637         0.527821     0.270976       2.538806
# std          1.741096         0.179060     0.194801       1.409928
# min          4.600000         0.120000     0.000000       0.900000
# 25%          7.100000         0.390000     0.090000       1.900000
# 50%          7.900000         0.520000     0.260000       2.200000
# 75%          9.200000         0.640000     0.420000       2.600000
# max         15.900000         1.580000     1.000000      15.500000
#
#                                                                           \
#          chlorides free_sulfur_dioxide total_sulfur_dioxide      density
# count  1599.000000         1599.000000          1599.000000  1599.000000
# mean      0.087467           15.874922            46.467792     0.996747
# std       0.047065           10.460157            32.895324     0.001887
# min       0.012000            1.000000             6.000000     0.990070
# 25%       0.070000            7.000000            22.000000     0.995600
# 50%       0.079000           14.000000            38.000000     0.996750
# 75%       0.090000           21.000000            62.000000     0.997835
# max       0.611000           72.000000           289.000000     1.003690
#
#                                  ... White Wines Stats                 \
#                 pH    sulphates  ...       citric_acid residual_sugar
# count  1599.000000  1599.000000  ...       4898.000000    4898.000000
# mean      3.311113     0.658149  ...          0.334192       6.391415
# std       0.154386     0.169507  ...          0.121020       5.072058
# min       2.740000     0.330000  ...          0.000000       0.600000
# 25%       3.210000     0.550000  ...          0.270000       1.700000
# 50%       3.310000     0.620000  ...          0.320000       5.200000
# 75%       3.400000     0.730000  ...          0.390000       9.900000
# max       4.010000     2.000000  ...          1.660000      65.800000
#
#                                                                           \
#          chlorides free_sulfur_dioxide total_sulfur_dioxide      density
# count  4898.000000         4898.000000          4898.000000  4898.000000
# mean      0.045772           35.308085           138.360657     0.994027
# std       0.021848           17.007137            42.498065     0.002991
# min       0.009000            2.000000             9.000000     0.987110
# 25%       0.036000           23.000000           108.000000     0.991723
# 50%       0.043000           34.000000           134.000000     0.993740
# 75%       0.050000           46.000000           167.000000     0.996100
# max       0.346000          289.000000           440.000000     1.038980
#
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000
#
# [8 rows x 24 columns]

# %%
combined_wines_desc_copy =combined_wines_desc.copy()

# %%
combined_wines_desc_copy.head()
# Out:
#       Red Wines Stats                                               \
#         fixed_acidity volatile_acidity  citric_acid residual_sugar
# count     1599.000000      1599.000000  1599.000000    1599.000000
# mean         8.319637         0.527821     0.270976       2.538806
# std          1.741096         0.179060     0.194801       1.409928
# min          4.600000         0.120000     0.000000       0.900000
# 25%          7.100000         0.390000     0.090000       1.900000
#
#                                                                           \
#          chlorides free_sulfur_dioxide total_sulfur_dioxide      density
# count  1599.000000         1599.000000          1599.000000  1599.000000
# mean      0.087467           15.874922            46.467792     0.996747
# std       0.047065           10.460157            32.895324     0.001887
# min       0.012000            1.000000             6.000000     0.990070
# 25%       0.070000            7.000000            22.000000     0.995600
#
#                                  ... White Wines Stats                 \
#                 pH    sulphates  ...       citric_acid residual_sugar
# count  1599.000000  1599.000000  ...       4898.000000    4898.000000
# mean      3.311113     0.658149  ...          0.334192       6.391415
# std       0.154386     0.169507  ...          0.121020       5.072058
# min       2.740000     0.330000  ...          0.000000       0.600000
# 25%       3.210000     0.550000  ...          0.270000       1.700000
#
#                                                                           \
#          chlorides free_sulfur_dioxide total_sulfur_dioxide      density
# count  4898.000000         4898.000000          4898.000000  4898.000000
# mean      0.045772           35.308085           138.360657     0.994027
# std       0.021848           17.007137            42.498065     0.002991
# min       0.009000            2.000000             9.000000     0.987110
# 25%       0.036000           23.000000           108.000000     0.991723
#
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
#
# [5 rows x 24 columns]

# %%
combined_wines_desc_copy.iloc[:,[3,6,9,10,1,11]]
# Out:
#       Red Wines Stats                                                 \
#        residual_sugar total_sulfur_dioxide    sulphates      alcohol
# count     1599.000000          1599.000000  1599.000000  1599.000000
# mean         2.538806            46.467792     0.658149    10.422983
# std          1.409928            32.895324     0.169507     1.065668
# min          0.900000             6.000000     0.330000     8.400000
# 25%          1.900000            22.000000     0.550000     9.500000
# 50%          2.200000            38.000000     0.620000    10.200000
# 75%          2.600000            62.000000     0.730000    11.100000
# max         15.500000           289.000000     2.000000    14.900000
#
#
#       volatile_acidity      quality
# count      1599.000000  1599.000000
# mean          0.527821     5.636023
# std           0.179060     0.807569
# min           0.120000     3.000000
# 25%           0.390000     5.000000
# 50%           0.520000     6.000000
# 75%           0.640000     6.000000
# max           1.580000     8.000000

# %%
cwdc = combined_wines_desc_copy

# %%
cwdc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, count to max
# Data columns (total 24 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   (Red Wines Stats, fixed_acidity)           8 non-null      float64
#  1   (Red Wines Stats, volatile_acidity)        8 non-null      float64
#  2   (Red Wines Stats, citric_acid)             8 non-null      float64
#  3   (Red Wines Stats, residual_sugar)          8 non-null      float64
#  4   (Red Wines Stats, chlorides)               8 non-null      float64
#  5   (Red Wines Stats, free_sulfur_dioxide)     8 non-null      float64
#  6   (Red Wines Stats, total_sulfur_dioxide)    8 non-null      float64
#  7   (Red Wines Stats, density)                 8 non-null      float64
#  8   (Red Wines Stats, pH)                      8 non-null      float64
#  9   (Red Wines Stats, sulphates)               8 non-null      float64
#  10  (Red Wines Stats, alcohol)                 8 non-null      float64
#  11  (Red Wines Stats, quality)                 8 non-null      float64
#  12  (White Wines Stats, fixed_acidity)         8 non-null      float64
#  13  (White Wines Stats, volatile_acidity)      8 non-null      float64
#  14  (White Wines Stats, citric_acid)           8 non-null      float64
#  15  (White Wines Stats, residual_sugar)        8 non-null      float64
#  16  (White Wines Stats, chlorides)             8 non-null      float64
#  17  (White Wines Stats, free_sulfur_dioxide)   8 non-null      float64
#  18  (White Wines Stats, total_sulfur_dioxide)  8 non-null      float64
#  19  (White Wines Stats, density)               8 non-null      float64
#  20  (White Wines Stats, pH)                    8 non-null      float64
#  21  (White Wines Stats, sulphates)             8 non-null      float64
#  22  (White Wines Stats, alcohol)               8 non-null      float64
#  23  (White Wines Stats, quality)               8 non-null      float64
# dtypes: float64(24)
# memory usage: 1.6+ KB

# %%
#You can observe that the mean value of sulfates and volatile acidity seem to be higher in red wine as compared to white wine.
cwdc.iloc[:,[3,6,9,10,1,11,15,18,21,22,13,23]]
# Out:
#       Red Wines Stats                                                 \
#        residual_sugar total_sulfur_dioxide    sulphates      alcohol
# count     1599.000000          1599.000000  1599.000000  1599.000000
# mean         2.538806            46.467792     0.658149    10.422983
# std          1.409928            32.895324     0.169507     1.065668
# min          0.900000             6.000000     0.330000     8.400000
# 25%          1.900000            22.000000     0.550000     9.500000
# 50%          2.200000            38.000000     0.620000    10.200000
# 75%          2.600000            62.000000     0.730000    11.100000
# max         15.500000           289.000000     2.000000    14.900000
#
#                                     White Wines Stats                       \
#       volatile_acidity      quality    residual_sugar total_sulfur_dioxide
# count      1599.000000  1599.000000       4898.000000          4898.000000
# mean          0.527821     5.636023          6.391415           138.360657
# std           0.179060     0.807569          5.072058            42.498065
# min           0.120000     3.000000          0.600000             9.000000
# 25%           0.390000     5.000000          1.700000           108.000000
# 50%           0.520000     6.000000          5.200000           134.000000
# 75%           0.640000     6.000000          9.900000           167.000000
# max           1.580000     8.000000         65.800000           440.000000
#
#
#          sulphates      alcohol volatile_acidity      quality
# count  4898.000000  4898.000000      4898.000000  4898.000000
# mean      0.489847    10.514267         0.278241     5.877909
# std       0.114126     1.230621         0.100795     0.885639
# min       0.220000     8.000000         0.080000     3.000000
# 25%       0.410000     9.500000         0.210000     5.000000
# 50%       0.470000    10.400000         0.260000     6.000000
# 75%       0.550000    11.400000         0.320000     6.000000
# max       1.080000    14.200000         1.100000     9.000000

# %%
#mean residual sugar appears higher in white than in red wines
cwdc.iloc[:,[3,11,15,23]]
# Out:
#       Red Wines Stats              White Wines Stats
#        residual_sugar      quality    residual_sugar      quality
# count     1599.000000  1599.000000       4898.000000  4898.000000
# mean         2.538806     5.636023          6.391415     5.877909
# std          1.409928     0.807569          5.072058     0.885639
# min          0.900000     3.000000          0.600000     3.000000
# 25%          1.900000     5.000000          1.700000     5.000000
# 50%          2.200000     6.000000          5.200000     6.000000
# 75%          2.600000     6.000000          9.900000     6.000000
# max         15.500000     8.000000         65.800000     9.000000

# %%
#white wines have higher average and max citric acid, but that may be an outlier's fault

cwdc.iloc[:,[2,11,14,23]]
# Out:
#       Red Wines Stats              White Wines Stats
#           citric_acid      quality       citric_acid      quality
# count     1599.000000  1599.000000       4898.000000  4898.000000
# mean         0.270976     5.636023          0.334192     5.877909
# std          0.194801     0.807569          0.121020     0.885639
# min          0.000000     3.000000          0.000000     3.000000
# 25%          0.090000     5.000000          0.270000     5.000000
# 50%          0.260000     6.000000          0.320000     6.000000
# 75%          0.420000     6.000000          0.390000     6.000000
# max          1.000000     8.000000          1.660000     9.000000

# %%
#max range of densities for white wines is much wider than for reds, but white average density is lower...
cwdc.iloc[:,[11,7,19,23]]
# Out:
#       Red Wines Stats              White Wines Stats
#               quality      density           density      quality
# count     1599.000000  1599.000000       4898.000000  4898.000000
# mean         5.636023     0.996747          0.994027     5.877909
# std          0.807569     0.001887          0.002991     0.885639
# min          3.000000     0.990070          0.987110     3.000000
# 25%          5.000000     0.995600          0.991723     5.000000
# 50%          6.000000     0.996750          0.993740     6.000000
# 75%          6.000000     0.997835          0.996100     6.000000
# max          8.000000     1.003690          1.038980     9.000000

# %%
#average free sulfur dioxide is higher in white wines on all measures
#Although it is naturally produced in small amounts by wine yeast during alcoholic fermentation, most of the SO2 found in wines has been put there by the winemaker. It is added at most stages of the white winemaking process, from crushing through to bottling. It is used less liberally during red winemaking, but with an almost mandatory addition being made following the completion of the malolactic fermentation of these wines. SO2 is added in the form of a powder, or is directly fed into the wine as a gas from a dosing gun.
#https://www.aromadictionary.com/articles/sulfurdioxide_article.html
#Free sulfur dioxide: the part of the sulfur dioxide that is added to a wine and that is lost into it is said to be bound, while the active part is said to be free. The winemaker will always try to get the highest proportion of free sulfur to bind. This variable is expressed in mg/dm3 in the data.
cwdc.iloc[:,[5, 17]]
# Out:
#           Red Wines Stats   White Wines Stats
#       free_sulfur_dioxide free_sulfur_dioxide
# count         1599.000000         4898.000000
# mean            15.874922           35.308085
# std             10.460157           17.007137
# min              1.000000            2.000000
# 25%              7.000000           23.000000
# 50%             14.000000           34.000000
# 75%             21.000000           46.000000
# max             72.000000          289.000000

# %%
#The first plot you should do is a pie chart, showing the quantity of red wines compared to the quantity of white wines.
import matplotlib.pyplot as plt

lbls = 'White Wines', 'Red Wines'
slices = [1599,4898]
cols = ['y','r']

plt.show()

plt.pie(slices,
        labels=lbls,
        colors=cols,
        startangle=90,
        shadow= True,
        autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x17ab8c850>,
#   <matplotlib.patches.Wedge at 0x17c784890>],
#  [Text(-0.7682629286682455, 0.787256039947672, 'White Wines'),
#   Text(0.7682628918141295, -0.7872560759126546, 'Red Wines')],
#  [Text(-0.4190525065463157, 0.42941238542600285, '24.6%'),
#   Text(0.4190524864440706, -0.42941240504326605, '75.4%')])

# %%
combined_wines_overall = pd.concat([red_wine, white_wine], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
combined_wines_overall
# Out:
#      Red Wines Stats                                                        \
#        fixed_acidity volatile_acidity citric_acid residual_sugar chlorides
# 0                7.4             0.70        0.00            1.9     0.076
# 1                7.8             0.88        0.00            2.6     0.098
# 2                7.8             0.76        0.04            2.3     0.092
# 3               11.2             0.28        0.56            1.9     0.075
# 4                7.4             0.70        0.00            1.9     0.076
# ...              ...              ...         ...            ...       ...
# 4893             NaN              NaN         NaN            NaN       NaN
# 4894             NaN              NaN         NaN            NaN       NaN
# 4895             NaN              NaN         NaN            NaN       NaN
# 4896             NaN              NaN         NaN            NaN       NaN
# 4897             NaN              NaN         NaN            NaN       NaN
#
#                                                                        ...  \
#      free_sulfur_dioxide total_sulfur_dioxide density    pH sulphates  ...
# 0                   11.0                 34.0  0.9978  3.51      0.56  ...
# 1                   25.0                 67.0  0.9968  3.20      0.68  ...
# 2                   15.0                 54.0  0.9970  3.26      0.65  ...
# 3                   17.0                 60.0  0.9980  3.16      0.58  ...
# 4                   11.0                 34.0  0.9978  3.51      0.56  ...
# ...                  ...                  ...     ...   ...       ...  ...
# 4893                 NaN                  NaN     NaN   NaN       NaN  ...
# 4894                 NaN                  NaN     NaN   NaN       NaN  ...
# 4895                 NaN                  NaN     NaN   NaN       NaN  ...
# 4896                 NaN                  NaN     NaN   NaN       NaN  ...
# 4897                 NaN                  NaN     NaN   NaN       NaN  ...
#
#      White Wines Stats                                                     \
#         residual_sugar chlorides free_sulfur_dioxide total_sulfur_dioxide
# 0                 20.7     0.045                45.0                170.0
# 1                  1.6     0.049                14.0                132.0
# 2                  6.9     0.050                30.0                 97.0
# 3                  8.5     0.058                47.0                186.0
# 4                  8.5     0.058                47.0                186.0
# ...                ...       ...                 ...                  ...
# 4893               1.6     0.039                24.0                 92.0
# 4894               8.0     0.047                57.0                168.0
# 4895               1.2     0.041                30.0                111.0
# 4896               1.1     0.022                20.0                110.0
# 4897               0.8     0.020                22.0                 98.0
#
#
#       density    pH sulphates alcohol quality quality_label
# 0     1.00100  3.00      0.45     8.8       6        medium
# 1     0.99400  3.30      0.49     9.5       6        medium
# 2     0.99510  3.26      0.44    10.1       6        medium
# 3     0.99560  3.19      0.40     9.9       6        medium
# 4     0.99560  3.19      0.40     9.9       6        medium
# ...       ...   ...       ...     ...     ...           ...
# 4893  0.99114  3.27      0.50    11.2       6        medium
# 4894  0.99490  3.15      0.46     9.6       5           low
# 4895  0.99254  2.99      0.46     9.4       6        medium
# 4896  0.98869  3.34      0.38    12.8       7        medium
# 4897  0.98941  3.26      0.32    11.8       6        medium
#
# [4898 rows x 26 columns]

# %%
cwo = combined_wines_overall

# %%
cwo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 26 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   (Red Wines Stats, fixed_acidity)           1599 non-null   float64
#  1   (Red Wines Stats, volatile_acidity)        1599 non-null   float64
#  2   (Red Wines Stats, citric_acid)             1599 non-null   float64
#  3   (Red Wines Stats, residual_sugar)          1599 non-null   float64
#  4   (Red Wines Stats, chlorides)               1599 non-null   float64
#  5   (Red Wines Stats, free_sulfur_dioxide)     1599 non-null   float64
#  6   (Red Wines Stats, total_sulfur_dioxide)    1599 non-null   float64
#  7   (Red Wines Stats, density)                 1599 non-null   float64
#  8   (Red Wines Stats, pH)                      1599 non-null   float64
#  9   (Red Wines Stats, sulphates)               1599 non-null   float64
#  10  (Red Wines Stats, alcohol)                 1599 non-null   float64
#  11  (Red Wines Stats, quality)                 1599 non-null   float64
#  12  (Red Wines Stats, quality_label)           1599 non-null   category
#  13  (White Wines Stats, fixed_acidity)         4898 non-null   float64
#  14  (White Wines Stats, volatile_acidity)      4898 non-null   float64
#  15  (White Wines Stats, citric_acid)           4898 non-null   float64
#  16  (White Wines Stats, residual_sugar)        4898 non-null   float64
#  17  (White Wines Stats, chlorides)             4898 non-null   float64
#  18  (White Wines Stats, free_sulfur_dioxide)   4898 non-null   float64
#  19  (White Wines Stats, total_sulfur_dioxide)  4898 non-null   float64
#  20  (White Wines Stats, density)               4898 non-null   float64
#  21  (White Wines Stats, pH)                    4898 non-null   float64
#  22  (White Wines Stats, sulphates)             4898 non-null   float64
#  23  (White Wines Stats, alcohol)               4898 non-null   float64
#  24  (White Wines Stats, quality)               4898 non-null   int64
#  25  (White Wines Stats, quality_label)         4898 non-null   category
# dtypes: category(2), float64(23), int64(1)
# memory usage: 928.3 KB

# %%
#Now create a plot to show the distribution of qualities. It should look similar to the one below
import seaborn as sns
